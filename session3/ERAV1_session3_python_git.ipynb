# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
# !ls gdrive/MyDrive/'Colab Notebooks'/ERAV1
# Out:
# 'Asgmnt ERA V1 S2.ipynb'   ERAV1_session3_python_git.ipynb   session1.ipynb

# %% [markdown]
# ```
# Topics
#   Difference between git and github
#   implicit and explicit in python
#
#
# Git command  -
#   git --version
#   git config -l
#   git config --global user.name "Tulsi"
#   git config --global user.email "tulsi@gmail.com"
#   mkdir s3
#   command+shift+plus to see hidden files
#   git init
#   touch index.txt -> create new file in folder(mac)
#   git status
#   git add .     -> add all files
#   git add index.txt. -> to add specific file
#   open index.txt -> to open file
#   --- if we changing files during staging so we have to again add the changing into staging area then commit
#   git comimit -m "adding files--"
#   git log -> tells about commit log
#   git checkout <e434684 - commitid> -> undo previous commit
#
# Commands -
#
#
# *   % git --version
# *   % git config -l
# *   % git config --global user.name "Tulsi"
# *.   % git config --global user.email "tulsi@gmail.com"
# *.  mkdir s3
#
#
#
#
#
# ```

# %%
#https://deepnote.com/workspace/the-admin-1957b0d5-55ec-485d-b760-1ff5e8265a44/project/ERA-V1-3b32b419-75e1-49b4-b4f7-85966d088843/notebook/Python%20101-600f83293f4647f3b64dcdf023889966
